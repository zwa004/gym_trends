# %%
import pandas as pd
import numpy as np

# %%
week_att_df = pd.read_csv('Resources\Class Attendance 11043 - 6-20-2022 - 6-24-2022.csv', nrows=1165)
week_att_df
# Out:
#                                              Textbox258  \
# 0     Class Attendance - Iron Tribe - Franklin (1104...
# 1     Class Attendance - Iron Tribe - Franklin (1104...
# 2     Class Attendance - Iron Tribe - Franklin (1104...
# 3     Class Attendance - Iron Tribe - Franklin (1104...
# 4     Class Attendance - Iron Tribe - Franklin (1104...
# ...                                                 ...
# 1160  Class Attendance - Iron Tribe - Franklin (1104...
# 1161  Class Attendance - Iron Tribe - Franklin (1104...
# 1162  Class Attendance - Iron Tribe - Franklin (1104...
# 1163  Class Attendance - Iron Tribe - Franklin (1104...
# 1164  Class Attendance - Iron Tribe - Franklin (1104...
#
#                                    Textbox345          DivisionDisplay  \
# 0     3 Classes - 4 Instructors - 242 Members  Division: Warren (2266)
# 1     3 Classes - 4 Instructors - 242 Members  Division: Warren (2266)
# 2     3 Classes - 4 Instructors - 242 Members  Division: Warren (2266)
# ...

# %%
week_att_df.drop(['Textbox258','Textbox345','DivisionDisplay','DistrictDisplay','SpecialCredit'], axis=1)
# Out:
#       Textbox331 Textbox332 Textbox67 TotalForClass2 Textbox33  Completed2  \
# 0             59     98.7 %    48.0 %          1,180     1,165         566
# 1             59     98.7 %    48.0 %          1,180     1,165         566
# 2             59     98.7 %    48.0 %          1,180     1,165         566
# 3             59     98.7 %    48.0 %          1,180     1,165         566
# 4             59     98.7 %    48.0 %          1,180     1,165         566
# ...          ...        ...       ...            ...       ...         ...
# 1160          59     98.7 %    48.0 %          1,180     1,165         566
# 1161          59     98.7 %    48.0 %          1,180     1,165         566
# 1162          59     98.7 %    48.0 %          1,180     1,165         566
# 1163          59     98.7 %    48.0 %          1,180     1,165         566
# 1164          59     98.7 %    48.0 %          1,180     1,165         566
#
# ...

# %%
pd.unique(week_att_df['ClassName'])
# Out:
# array(['Power (52741)', 'PRIME (57332)', 'Push (52476)'], dtype=object)
